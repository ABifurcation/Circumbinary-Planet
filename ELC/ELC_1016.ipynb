# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fmin
from scipy.optimize import curve_fit

# %%
basedir = '/Users/laote/sdsu/Research/binary/ELC/ELC_rt'

# %%
def light_curve(lc_dir,norm=1,xlim=(0,0),ylim=(0,0),look=False):
    data = np.genfromtxt(lc_dir,names="time,flux")
    Time = data['time']
    flux = data['flux']

#   norm ot 0 
    if norm == 0:
        min_flux = np.min(np.append(flux[int(len(flux)*0.05):int(len(flux)*0.4)],\
                                    flux[int(len(flux)*0.6):-int(len(flux)*0.05)]))
        norm_flux = (flux - np.median(flux))/(np.median(flux) - min_flux)
#   norm to 1
    if norm == 1:
        norm_flux = flux
#         norm_flux = flux/np.median(flux)
#   norm to std
    if norm == 2:
        norm_flux = (flux - np.median(flux))/np.std(flux)
#   norm to max - min
    if norm == 3:
        norm_flux = (flux - np.median(flux))/(np.max(flux) - np.min(flux))

    if look == True:
        plt.figure(figsize=(10,5))
        plt.plot(Time,norm_flux,'c')
        plt.plot(Time,norm_flux,'r.')
        plt.xlabel('time');plt.ylabel('flux')
        if xlim[0] != 0:
            plt.title('%s_%s'%(xlim[0],xlim[1]))
            plt.xlim(xlim[0],xlim[1])
        if ylim[0] != 0:
            plt.ylim(ylim[0],ylim[1])
        plt.grid()
        plt.show()
    
    w = (Time > xlim[0]) & (Time < xlim[1])
    return Time[w],norm_flux[w]

# %%
def gaussian_func(ys, a1, cy1, sigma1):
    p1 = np.exp(-(ys - cy1)**2 / 2 / sigma1**2) 
#     p1 /= p1.max()
    
    return a1 * p1

# %%
light_curve(basedir+'/modelU_183.linear',xlim=(-70,1500),look=True)
light_curve(basedir+'/ELCresidualsU_5675.fold',xlim=(-70,1500),look=True)

light_curve(basedir+'/modelU_fit2.linear',xlim=(-70,1500),look=True)
light_curve(basedir+'/ELCresidualsU_fit2.fold',xlim=(-70,1500),look=True)

1
# Out:
# 1

# %%
# rl=96;rr=102
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# rl=230;rr=240
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# rl=325;rr=335
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# rl=345;rr=350
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# rl=580;rr=590
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# rl=830;rr=836
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# rl=1044;rr=1050
# light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
# light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

# %%
rl=[-42,-25,15,35,72,92 ,112,130,150,170,188,208,245,268,287,307,325,345,364,
    383,403,422,442,576,596,615,636,653,674,694,713,733,752,771,790,810,
    928,945,965,985,1005,1024,1042,1062,1082,1101,1140,1160,1180,1316,
    1335,1354,1372,1390]
rr=[-35,-15,25,45,85,105,120,140,160,180,200,220,258,276,295,315,334,354,374,
    395,412,432,452,586,608,627,647,667,685,705,725,743,764,782,801,821,
    936,956,976,996,1016,1035,1052,1073,1093,1112,1151,1171,1191,1324,
    1343,1363,1383,1402] 

for i in range(len(rl)):
#     light_curve(basedir+'/modelU_183.linear',xlim=(rl[i],rr[i]),look=True)
    light_curve(basedir+'/ELCresidualsU_Tori.fold',xlim=(rl[i],rr[i]),look=True)

# %%
se = [-21,18,37,76,95,115,134,154,173,193,212,251,270,289.5,367,386,406,425,445,581,600,619,
      658,678,697,717,736,755,775,794,813,949,969,989,1007,1027,1066,1085,1143,1163,1182,
      1337.5,1357,1376,1396]
pe = [-17.2,21.5,41,80,138,157.5,177,196.3,215.5,254.5,274,293.5,313,332,351.5,371,390.5,
      409.5,429,449,604,623.3,642.4,662,681.5,701,759,779,798,817,934,953,973,992,1011,1031,1050,
      1069.5,1089,1108.5,1147,1167,1186,1322,1341.5,1361,1380,1399]
point_7x = [21.54374865,   79.75952294,   79.77995642,  118.6029157,   118.70508027,
  273.97653166,  289.4247014,   289.46556961,  351.48377308,  386.40593221,
  386.65114212,  405.75699456,  448.50426508,  448.52469849,  662.11313648,
  762.89511735,  817.22861101,  817.24904447,  817.26947782,  933.83945495,
  991.89031829, 1011.83369352, 1011.85412743, 1046.4694907,  1046.48992487,
 1069.64203178, 1085.17217344, 1085.19260783, 1085.21304212, 1143.34847987,
 1185.93248181, 1201.64576941, 1201.66620261, 1399.43890235]
point_7y = [0.00141596, -0.00126065, -0.00176185, -0.00205085,  0.00195642, -0.00217057,
 -0.00108022,  0.00144897,  0.00187514,  0.00152955,  0.0013218,   0.00177092,
 -0.00185626, -0.00265347, -0.00139782, -0.00151088, -0.00198105, -0.0019004,
 -0.0015964,   0.00174047, -0.00130003, -0.00121831, -0.00136789, -0.00157143,
 -0.00130864,  0.00128351, -0.00196134,  0.00342631, -0.0016463,  -0.00127667,
  0.00123179,  0.0016073,   0.00170896,  0.00142461]

# %%
Q99 = np.genfromtxt(basedir+'/newkid010753734.Q99',names='t,f,ef,n')
for i in range(len(pe)):
    t,f = light_curve(basedir+'/ELCresidualsU_Tori.fold',xlim=(pe[i]-1.75,pe[i]+1.75))
    Ql = np.where(Q99['t']==t[0])[0][0]
    Qr = np.where(Q99['t']==t[-1])[0][0]
    popt,pcov=curve_fit(gaussian_func,t,f,p0=(0.0025,t[np.argmax(f)],0.25),maxfev = 11800)
#     Q99['f'][Ql:Qr+1] = Q99['f'][Ql:Qr+1]-gaussian_func(Q99['t'][Ql:Qr+1],  popt[0], popt[1],  popt[2])
    fitx = np.linspace(pe[i]-1.75,pe[i]+1.75,1000)
    fity = gaussian_func(fitx,  popt[0], popt[1],  popt[2])
    plt.figure(figsize=(15,7))
    plt.plot(t,f,'k.')
    plt.plot(fitx,fity,'r')
    plt.xlabel('BJD-2455000')
    plt.ylabel('flux residual')
#     plt.plot(t,f-gaussian_func(t,  popt[0], popt[1],  popt[2]),'k')
    for j in range(len(point_7x)):
        if (point_7x[j] < np.max(t)) & (point_7x[j] > np.min(t)):
            plt.plot(point_7x[j],point_7y[j],'bo')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.

# %%
for i in range(len(se)):
    t,f = light_curve(basedir+'/ELCresidualsU_Tori.fold',xlim=(se[i]-1.75,se[i]+1.75))
    Ql = np.where(Q99['t']==t[0])[0][0]
    Qr = np.where(Q99['t']==t[-1])[0][0]
    popt,pcov=curve_fit(gaussian_func,t,f,p0=(0.002,t[np.argmax(f)],0.25),maxfev = 11800)
    Q99['f'][Ql:Qr+1] = Q99['f'][Ql:Qr+1]-gaussian_func(Q99['t'][Ql:Qr+1],  popt[0], popt[1],  popt[2])
#     fitx = np.linspace(se[i]-1.75,se[i]+1.75,1000)
#     fity = gaussian_func(fitx,  popt[0], popt[1],  popt[2])
#     plt.figure(figsize=(15,7))
#     plt.plot(t,f,'c.')
#     plt.plot(fitx,fity,'r')
#     plt.plot(t,f-gaussian_func(t,  popt[0], popt[1],  popt[2]),'k')

# %%
# f = open(basedir+'/kid010753734.Q99_Tfit','w')
# for i in range(len(Q99['f'])):
#     f.write('%20.11f %20.11f %20.11f %20.11f\n'%(Q99['t'][i],Q99['f'][i],Q99['ef'][i],Q99['n'][i]))
# f.close()
# Q99 = np.genfromtxt(basedir+'/newkid010753734.Q99',names='t,f,ef,n')
# Q99_fit = np.genfromtxt(basedir+'/kid010753734.Q99_Tfit',names='t,f,ef,n')

# %%
plt.figure(figsize=(15,7))
plt.plot(Q99['t'],Q99['f']-Q99_fit['f'],'.r--')

# %%
(Q99['f']-Q99_fit['f'])[100:300]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000008e-11,
#        5.00000041e-11, 3.10000026e-10, 1.91999994e-09, 5.35200000e-08,
#        2.42180000e-07, 9.89510000e-07, 3.65026000e-06, 3.65595100e-05,
#        9.92592700e-05, 1.07604147e-03, 1.94131398e-03, 3.16216374e-03,
# ...

# %%
Q99 = np.genfromtxt(basedir+'/kid010753734.Q99_Tfit',names='t,f,ef,n')
res100 = np.genfromtxt(basedir+'/res_100.txt',names='t')

# %%
for i in range(len(res100)):
    pos = np.argmin(np.abs(Q99['t']-res100['t'][i]))
    Q99['ef'][pos] = Q99['ef'][pos]*30

# %%
f = open(basedir+'/kid010753734.Q99_resfit','w')
for i in range(len(Q99['f'])):
    f.write('%22.11f %22.11f %22.11f %22.11f\n'%(Q99['t'][i],Q99['f'][i],Q99['ef'][i],Q99['n'][i]))
f.close()
