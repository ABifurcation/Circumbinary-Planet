# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fmin
from scipy.optimize import curve_fit

# %%
basedir = '/Users/laote/sdsu/Research/binary/ELC/ELC_rt'

# %%
def light_curve(lc_dir,norm=1,xlim=(0,0),ylim=(0,0),look=False):
    data = np.genfromtxt(lc_dir,names="time,flux")
    Time = data['time']
    flux = data['flux']

#   norm ot 0 
    if norm == 0:
        min_flux = np.min(np.append(flux[int(len(flux)*0.05):int(len(flux)*0.4)],\
                                    flux[int(len(flux)*0.6):-int(len(flux)*0.05)]))
        norm_flux = (flux - np.median(flux))/(np.median(flux) - min_flux)
#   norm to 1
    if norm == 1:
        norm_flux = flux
#         norm_flux = flux/np.median(flux)
#   norm to std
    if norm == 2:
        norm_flux = (flux - np.median(flux))/np.std(flux)
#   norm to max - min
    if norm == 3:
        norm_flux = (flux - np.median(flux))/(np.max(flux) - np.min(flux))

    if look == True:
        plt.figure(figsize=(10,5))
        plt.plot(Time,norm_flux,'c')
        plt.plot(Time,norm_flux,'r.')
        plt.xlabel('time');plt.ylabel('flux')
        if xlim[0] != 0:
            plt.title('%s_%s'%(xlim[0],xlim[1]))
            plt.xlim(xlim[0],xlim[1])
        if ylim[0] != 0:
            plt.ylim(ylim[0],ylim[1])
        plt.grid()
        plt.show()
    
    w = (Time > xlim[0]) & (Time < xlim[1])
    return Time[w],norm_flux[w]

# %%
def gaussian_func(ys, a1, cy1, sigma1):
    p1 = np.exp(-(ys - cy1)**2 / 2 / sigma1**2) 
#     p1 /= p1.max()
    
    return a1 * p1

# %%
light_curve(basedir+'/modelU_183.linear',xlim=(-70,1500),look=True)
light_curve(basedir+'/ELCresidualsU_183.fold',xlim=(-70,1500),look=True)

light_curve(basedir+'/modelU_fit1.linear',xlim=(-70,1500),look=True)
light_curve(basedir+'/ELCresidualsU_fit1.fold',xlim=(-70,1500),look=True)
# Out:
# (array([ -41.35301857,  -41.33258428,  -41.2917154 , ..., 1414.53975662,
#         1414.56019085, 1414.58062509]),
#  array([-9.08898680e-05,  1.39506802e-04,  1.07003142e-04, ...,
#         -1.45999278e-04,  4.58295620e-05, -2.30070780e-05]))

# %%
rl=96;rr=102
light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

rl=230;rr=240
light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

rl=325;rr=335
light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

rl=345;rr=350
light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

rl=580;rr=590
light_curve(basedir+'/modelU_23.linear',xlim=(rl,rr),look=True)
light_curve(basedir+'/ELCresidualsU_23.fold',xlim=(rl,rr),look=True)

#          1.08210371e-04,  2.04185704e-04,  4.35183590e-05,  3.45414707e-04,
#          1.38741056e-04, -5.36885059e-04, -3.87888305e-04,  5.15397600e-05,
#          9.11786000e-05,  9.35122810e-05, -1.52672115e-04, -4.45772450e-05,
#          1.63075835e-04, -2.08046465e-04,  1.67531050e-05, -1.19098215e-04,
#         -6.73810350e-05,  3.08472635e-04, -2.42940985e-04, -8.85673650e-05,
#         -3.54024750e-05, -4.56601850e-05, -2.17028775e-04, -1.42879355e-04,
#         -8.75726500e-06,  2.88323775e-04,  6.04314150e-05, -1.05800375e-04,
#         -1.48540565e-04,  1.44680975e-04,  1.26615650e-05, -1.50793500e-06,
#         -1.29047535e-04, -1.51701915e-04,  2.04884225e-04,  1.11978565e-04,
#         -1.02906125e-04,  4.68401125e-04, -2.52723075e-04,  4.87154650e-05,
#          1.89019505e-04, -8.98042850e-05,  1.97078255e-04,  1.61337275e-04,
#         -5.12958750e-05, -9.76427250e-05,  8.68123950e-05, -1.94469485e-04,
#         -1.28622745e-04, -2.93273650e-05]))

# %%
rl=[-42,-25,15,35,72,92 ,112,130,150,170,188,208,245,268,287,307,325,345,364,
    383,403,422,442,576,596,615,636,653,674,694,713,733,752,771,790,810,
    928,945,965,985,1005,1024,1042,1062,1082,1101,1140,1160,1180,1316,
    1335,1354,1372,1390]
rr=[-35,-15,25,45,85,105,120,140,160,180,200,220,258,276,295,315,334,354,374,
    395,412,432,452,586,608,627,647,667,685,705,725,743,764,782,801,821,
    936,956,976,996,1016,1035,1052,1073,1093,1112,1151,1171,1191,1324,
    1343,1363,1383,1402] 

for i in range(len(rl)):
#     light_curve(basedir+'/modelU_183.linear',xlim=(rl[i],rr[i]),look=True)
    light_curve(basedir+'/ELCresidualsU_183.fold',xlim=(rl[i],rr[i]),look=True)

# %%
se = [-21,18,37,76,95,115,134,154,173,193,212,251,270,289.5,367,386,406,425,445,581,600,619,
      658,678,697,717,736,755,775,794,813,949,969,989,1007,1027,1066,1085,1143,1163,1182,
      1337.5,1357,1376,1396]
pe = [-17.2,21.5,41,80,118.7,138,157.5,177,196.3,215.5,254.5,274,293.5,313,332,351.5,371,390.5,
      409.5,429,449,604,623.3,642.4,662,681.5,701,759,779,798,817,934,953,973,992,1011,1031,1050,
      1069.5,1089,1108.5,1147,1167,1186,1322,1341.5,1361,1380,1399]

# %%
Q99 = np.genfromtxt(basedir+'/kid010753734.Q99',names='t,f,ef,n')
for i in range(len(pe)):
    t,f = light_curve(basedir+'/ELCresidualsU_183.fold',xlim=(pe[i]-1.75,pe[i]+1.75))
    Ql = np.where(Q99['t']==t[0])[0][0]
    Qr = np.where(Q99['t']==t[-1])[0][0]
    popt,pcov=curve_fit(gaussian_func,t,f,p0=(0.0025,t[np.argmax(f)],0.25))
    Q99['f'][Ql:Qr+1] = Q99['f'][Ql:Qr+1]-gaussian_func(Q99['t'][Ql:Qr+1],  popt[0], popt[1],  popt[2])
#     fitx = np.linspace(pe[i]-1.75,pe[i]+1.75,1000)
#     fity = gaussian_func(fitx,  popt[0], popt[1],  popt[2])
#     plt.figure(figsize=(15,7))
#     plt.plot(t,f,'c.')
#     plt.plot(fitx,fity,'r')
#     plt.plot(t,f-gaussian_func(t,  popt[0], popt[1],  popt[2]),'k')

# %%
for i in range(len(se)):
    t,f = light_curve(basedir+'/ELCresidualsU_183.fold',xlim=(se[i]-1.75,se[i]+1.75))
    Ql = np.where(Q99['t']==t[0])[0][0]
    Qr = np.where(Q99['t']==t[-1])[0][0]
    popt,pcov=curve_fit(gaussian_func,t,f,p0=(0.0025,t[np.argmax(f)],0.25))
    Q99['f'][Ql:Qr+1] = Q99['f'][Ql:Qr+1]-gaussian_func(Q99['t'][Ql:Qr+1],  popt[0], popt[1],  popt[2])
#     fitx = np.linspace(se[i]-1.75,se[i]+1.75,1000)
#     fity = gaussian_func(fitx,  popt[0], popt[1],  popt[2])
#     plt.figure(figsize=(15,7))
#     plt.plot(t,f,'c.')
#     plt.plot(fitx,fity,'r')
#     plt.plot(t,f-gaussian_func(t,  popt[0], popt[1],  popt[2]),'k')

# %%
f = open(basedir+'/kid010753734.Q99_fit2','w')
for i in range(len(Q99['f'])):
    f.write('%20.11f %20.11f %20.11f %20.11f\n'%(Q99['t'][i],Q99['f'][i],Q99['ef'][i],Q99['n'][i]))
f.close()
Q99 = np.genfromtxt(basedir+'/kid010753734.Q99',names='t,f,ef,n')
Q99_fit = np.genfromtxt(basedir+'/kid010753734.Q99_fit2',names='t,f,ef,n')

# %%
plt.figure(figsize=(15,7))
plt.plot(Q99['t'],Q99['f']-Q99_fit['f'],'.r--')

# %%
(Q99['f']-Q99_fit['f'])[100:300]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000008e-11,
#        4.00000033e-11, 2.50000021e-10, 1.43000001e-09, 3.50800000e-08,
#        1.50330000e-07, 5.84930000e-07, 2.06657000e-06, 1.93123500e-05,
#        5.10822100e-05, 5.29856030e-04, 9.52754660e-04, 1.55560476e-03,
#        2.30628534e-03, 3.10473176e-03, 3.79517481e-03, 4.21245513e-03,
#        4.24556220e-03, 3.88536021e-03, 3.22867094e-03, 2.43620210e-03,
#        1.03843489e-03, 5.86622100e-04, 3.00907340e-04, 1.40153350e-04,
#        5.92748600e-05, 2.27632300e-05, 7.93768000e-06, 2.51333000e-06,
#        7.22610000e-07, 4.47199999e-08, 9.62999991e-09, 1.88000004e-09,
#        3.29999916e-10, 1.00000008e-11, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000008e-11,
#        3.20000026e-10, 5.78000003e-09, 7.71999999e-08, 7.73880000e-07,
#        5.81732000e-06, 3.27931900e-05, 1.38629370e-04, 4.39485150e-04,
#        1.04483750e-03, 1.86279537e-03, 2.49055000e-03, 2.49712353e-03,
#        1.87758023e-03, 1.05869906e-03, 4.47671730e-04, 1.41957420e-04,
#        3.37576900e-05, 8.05090000e-07, 8.07400000e-08, 6.07000006e-09,
#        3.40000028e-10, 1.00000008e-11, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])
