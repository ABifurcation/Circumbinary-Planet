# %%
# %run Binary_function.ipynb

# %% [markdown]
# **known fake signal**
#
# 1. tic00425935689
# 2. tic00393347190
# 3. tic00401926767
# 4. tic00349572805
# 5. tic00333642126 sec5
# 6. tic00350518984 sec2
# 7. tic00234288940_SEC001
# 8. tic00388086679_SEC007
# 9. tic00229495981_SEC014
# 10. tic00314867169_SEC002
# 11. tic00036734222_SEC009
# 12. tic00071531463
# 13. tic00375422201
# 14. tic00167983141
# 15. tic00384031569
# 16. tic00455509774
#
# **known real signal**
#
# 1. tic00260128333
#
# **signal**
#
# 1. tic00140760434
# 2. tic00198418712 pulsing
#
# **Two binary star**
# 1. tic00319558163 tic00319558164
# 2. tic00220422453 tic00220422451
# 3. tic00375422201
#
# **High ecc orbit**
# 1. tic00149503323 - 0.1
# 2. tic00229689154 - 0.2
# 3. tic00232646332 - 0.2
# 4. tic00234347951 - 0.2
# 5. tic00238202532 - 0.2
# 6. tic00255619508 - 0.2
# 7. tic00260542524 - 0.2
# 8. tic00278826996 - 0.2
# 9. tic00369711521 - 0.2

# %%
checkdir = '/Users/laote/sdsu/Research/binary/curve_bin/Binary_good/tic00260128333_SEC006_LC.txt'
eye_check(checkdir)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:63: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
checkdir = '/Users/laote/sdsu/Research/binary/curve_bin/Binary_good/tic00402980664_SEC019_LC.txt'
eye_check(checkdir)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:63: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
checkdir = '/Users/laote/sdsu/Research/binary/curve_bin/Binary_good/tic00375422201_SEC015_LC.txt'
eye_check(checkdir,(3710,3723))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:63: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
checkdir = '/Users/laote/sdsu/Research/binary/curve_bin/Binary_good/tic00455509774_SEC012_LC.txt'
eye_check(checkdir,limx=(3650,3655))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:63: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
checkdir = '/Users/laote/sdsu/Research/binary/curve_bin/Binary_good/tic00203001339_SEC015_LC.txt'
eye_check(checkdir,(3713,3725),(0.98,1.005))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:63: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
checkdir = '/Users/laote/sdsu/Research/binary/curve_bin/Binary_good/tic00384031569_SEC009_LC.txt'
eye_check(checkdir)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:63: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
